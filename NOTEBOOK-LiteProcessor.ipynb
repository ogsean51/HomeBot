# %%
import tensorflow as tf
import tensorflow_io as tfio
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def load_wav(filename):
    file_contents = tf.io.read_file(filename)
    wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
    
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    
    wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
    return wav

# %%
def preprocess(file_path, label):
    wav = load_wav(file_path)
    wav = wav[:48000]
    zero_padding = tf.zeros([48000] - tf.shape(wav), dtype=tf.float32)
    wav = tf.concat([zero_padding, wav],0)
    spectrogram = tf.signal.stft(wav, frame_length=320, frame_step=32)
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.expand_dims(spectrogram, axis=2)
    return spectrogram

# %%
EVAL = os.path.join('Process')

eval = tf.data.Dataset.list_files(EVAL +'/*.wav')

data = tf.data.Dataset.zip((eval, tf.data.Dataset.from_tensor_slices(tf.ones(len(eval)))))

filepath, label = data.shuffle(buffer_size=10000).as_numpy_iterator().next()
spectrogram, label = preprocess(filepath, label)
print(filepath)
plt.figure(figsize=(30,20))
plt.imshow(tf.transpose(spectrogram)[0])
plt.show
# Out:
# b'Process\\process.wav'
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
eval = tf.data.Dataset.list_files(EVAL +'/*.wav')

# %%
audio = []
for e in eval:
    audio.append(tfio.audio.AudioIOTensor(e))

# %%
data = tf.data.Dataset.zip((eval, tf.data.Dataset.from_tensor_slices(tf.ones(len(eval)))))

# %%
data = data.map(preprocess)
# Out:
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.

# %%
interpreter = tf.lite.Interpreter(model_path="./Training/processor.tflite")

# %%
input_details = interpreter.get_input_details()    
output_details = interpreter.get_output_details()

# %%
interpreter.allocate_tensors()

# %%
input_shape = input_details[0]['shape']

# %%
input_data = np.array(np.random.random_sample(input_shape), dtype=np.uint8)

# %%
#Predict model with processed data  
interpreter.set_tensor(input_details[0]['index'], [eval])
interpreter.invoke()            
prediction = interpreter.get_tensor(output_details[0]['index'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 #Predict model with processed data
# ----> 2 interpreter.set_tensor(input_details[0]['index'], [eval])
#       3 interpreter.invoke()
#       4 prediction = interpreter.get_tensor(output_details[0]['index'])
#
# File o:\Python\lib\site-packages\tensorflow\lite\python\interpreter.py:697, in Interpreter.set_tensor(self, tensor_index, value)
#     681 def set_tensor(self, tensor_index, value):
#     682   """Sets the value of the input tensor.
#     683
#     684   Note this copies data in `value`.
#    (...)
#     695     ValueError: If the interpreter could not set the tensor.
#     696   """
# --> 697   self._interpreter.SetTensor(tensor_index, value)
#
# ValueError: Cannot set tensor: Got value of type STRING but expected type FLOAT32 for input 0, name: serving_default_conv2d_input:0
